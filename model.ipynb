# %%
import numpy as np 
import pandas as pd 
import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
from tensorflow.keras.applications import VGG16, InceptionResNetV2
from keras import regularizers
from tensorflow.keras.optimizers import Adam,RMSprop,SGD,Adamax

train_dir = "train"
test_dir = "test"
img_size = 48

train_datagen = ImageDataGenerator(
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    rescale=1./255,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="training"
)

validation_generator = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_size, img_size),
    batch_size=64,
    color_mode="grayscale",
    class_mode="categorical",
    subset="validation"
)

# بناء النموذج
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(7, activation='softmax')  
])

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

epochs = 50  
model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=epochs
)

model.save('model_fer2013.h5')  # سيحفظ النموذج هنا
print("Model saved as model_fer2013.h5")
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Epoch 1/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 128s 338ms/step - accuracy: 0.1828 - loss: 2.8573 - val_accuracy: 0.1533 - val_loss: 2.5535
# Epoch 2/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 107s 297ms/step - accuracy: 0.2256 - loss: 2.3948 - val_accuracy: 0.2949 - val_loss: 1.9164
# Epoch 3/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 103s 287ms/step - accuracy: 0.2488 - loss: 2.2338 - val_accuracy: 0.3404 - val_loss: 1.8228
# Epoch 4/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 282ms/step - accuracy: 0.2691 - loss: 2.1305 - val_accuracy: 0.3564 - val_loss: 1.8471
# Epoch 5/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 282ms/step - accuracy: 0.2936 - loss: 2.0172 - val_accuracy: 0.3472 - val_loss: 1.8631
# Epoch 6/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 104s 289ms/step - accuracy: 0.3033 - loss: 1.9635 - val_accuracy: 0.3632 - val_loss: 1.8125
# Epoch 7/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 282ms/step - accuracy: 0.3301 - loss: 1.8763 - val_accuracy: 0.3801 - val_loss: 1.6532
# Epoch 8/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 102s 284ms/step - accuracy: 0.3407 - loss: 1.8228 - val_accuracy: 0.3661 - val_loss: 1.7511
# Epoch 9/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 280ms/step - accuracy: 0.3483 - loss: 1.7713 - val_accuracy: 0.3642 - val_loss: 1.7743
# Epoch 10/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 279ms/step - accuracy: 0.3557 - loss: 1.7359 - val_accuracy: 0.3907 - val_loss: 1.6595
# Epoch 11/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 279ms/step - accuracy: 0.3717 - loss: 1.6846 - val_accuracy: 0.4095 - val_loss: 1.5586
# Epoch 12/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 281ms/step - accuracy: 0.3769 - loss: 1.6582 - val_accuracy: 0.4264 - val_loss: 1.5368
# Epoch 13/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 100s 279ms/step - accuracy: 0.3925 - loss: 1.6271 - val_accuracy: 0.3931 - val_loss: 1.5613
# Epoch 14/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 101s 282ms/step - accuracy: 0.3985 - loss: 1.6022 - val_accuracy: 0.4271 - val_loss: 1.4768
# Epoch 15/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 102s 283ms/step - accuracy: 0.4071 - loss: 1.5699 - val_accuracy: 0.3951 - val_loss: 1.6062
# Epoch 16/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 102s 283ms/step - accuracy: 0.4056 - loss: 1.5661 - val_accuracy: 0.4391 - val_loss: 1.4618
# Epoch 17/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 112s 312ms/step - accuracy: 0.4152 - loss: 1.5343 - val_accuracy: 0.4323 - val_loss: 1.4833
# Epoch 18/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 98s 272ms/step - accuracy: 0.4180 - loss: 1.5243 - val_accuracy: 0.4355 - val_loss: 1.4873
# Epoch 19/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 90s 251ms/step - accuracy: 0.4285 - loss: 1.4915 - val_accuracy: 0.4466 - val_loss: 1.4605
# Epoch 20/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 125s 349ms/step - accuracy: 0.4381 - loss: 1.4838 - val_accuracy: 0.4576 - val_loss: 1.4257
# Epoch 21/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 124s 346ms/step - accuracy: 0.4398 - loss: 1.4640 - val_accuracy: 0.4527 - val_loss: 1.4355
# Epoch 22/50
# 359/359 ━━━━━━━━━━━━━━━━━━━━